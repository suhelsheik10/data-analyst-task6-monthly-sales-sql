# %%
import pandas as pd

# %%
# Step 2: Load the dataset (replace filename if different)
df = pd.read_csv("/content/sample_data/online_sales_superstore.csv")

# %%
# Step 3: View first few rows
df.head()
# Out:
#          order_id  order_date       product_id    amount
# 0  CA-2016-152156  2016-08-11  FUR-BO-10001798  261.9600
# 1  CA-2016-152156  2016-08-11  FUR-CH-10000454  731.9400
# 2  CA-2016-138688  2016-12-06  OFF-LA-10000240   14.6200
# 3  US-2015-108966  2015-11-10  FUR-TA-10000577  957.5775
# 4  US-2015-108966  2015-11-10  OFF-ST-10000760   22.3680

# %%
# Step 4: Keep only required columns
df = df[['order_id', 'order_date', 'product_id', 'amount']]
df.columns = ['order_id', 'order_date', 'product_id', 'amount']  # Rename for SQL

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format='mixed', dayfirst=True).dt.strftime('%Y-%m-%d')

# %%
# Convert mixed date formats to consistent format
df['order_date'] = pd.to_datetime(df['order_date'], format='mixed', dayfirst=True).dt.strftime('%Y-%m-%d')

# %%
# Step 6: Check for nulls
print(df.isnull().sum())
# Out:
# order_id      0
# order_date    0
# product_id    0
# amount        0
# dtype: int64

# %%
df.tail(20)
# Out:
#             order_id  order_date       product_id   amount
# 9974  US-2016-103674  2016-06-12  OFF-AR-10004752   18.690
# 9975  US-2016-103674  2016-06-12  OFF-PA-10000743   13.360
# 9976  US-2016-103674  2016-06-12  TEC-PH-10002496  249.584
# 9977  US-2016-103674  2016-06-12  OFF-FA-10003467   13.860
# 9978  US-2016-103674  2016-06-12  OFF-BI-10003727   13.376
# 9979  US-2016-103674  2016-06-12  OFF-BI-10002026  437.472
# 9980  US-2015-151435  2015-06-09  FUR-TA-10001039   85.980
# 9981  CA-2017-163566  2017-03-08  OFF-LA-10004484   16.520
# 9982  US-2016-157728  2016-09-22  OFF-PA-10002195   35.560
# 9983  US-2016-157728  2016-09-22  TEC-PH-10001305   97.980
# 9984  CA-2015-100251  2015-05-17  OFF-LA-10003766   31.500
# 9985  CA-2015-100251  2015-05-17  OFF-SU-10000898   55.600
# 9986  CA-2016-125794  2016-09-29  TEC-AC-10003399   36.240
# 9987  CA-2017-163629  2017-11-17  TEC-AC-10001539   79.990
# 9988  CA-2017-163629  2017-11-17  TEC-PH-10004006  206.100
# ...

# %%
# Step 7: Save cleaned data
df.to_csv("online_sales.csv", index=False)
files.download("online_sales.csv")
